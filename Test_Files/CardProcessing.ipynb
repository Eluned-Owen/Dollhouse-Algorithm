# %% [markdown]
# <h1>Card Processing</h1>
# <p>Important note: this document was originally used to create the first verions of the Game_Flow.py file, it has since been used to debug the Pandas CSV database</p>
# <p>This program reads the serial port from COM4 (Arduino Leonardo running the NFC-Input code) and saves the data a a string. The data exported from the ardunio are the behavioural surplus cards' NFC reader tags, written in the app "NFC Tools" for the IPhone.</p>

# %%
#pip install pySerial
# Out:
# This is here to show that the import is working

# %%
#If there's bytes waiting at the input buffer, read them and save them to a card variable
#from Main.py import ser 
#if ser.in_waiting > 0:
#    available = ser.read(ser.in_waiting)
#    print(f"Available data: {available}")
#    card = availablezz
# Out:
# Available data: b'16\r\n\r\n\r\n\r\n18\r\n\r\n\r\n\r\n'

# %%
#As the card variable is a byte, convert card to a string using utf-8 \r\n\r\n\r\n\r\n
#print(type(card))
#decode_card = card.decode("UTF-8")
#clean_card = decode_card[5:]
#clean_card = final_card[:-4]
#final_card = clean_card.strip()
#clean_card = decode_card.strip()
#clean_card = decode_card.split()
#final_card = [int(i) for i in clean_card]
#print(final_card)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #As the card variable is a byte, convert card to a string using utf-8 \r\n\r\n\r\n\r\n
#       2 #print(type(card))
# ----> 3 decode_card = card.decode("UTF-8")
#       4 #clean_card = decode_card[5:]
#       5 #clean_card = final_card[:-4]
#       6 #final_card = clean_card.strip()
#       7 #clean_card = decode_card.strip()
#       8 clean_card = decode_card.split()
#
# NameError: name 'card' is not defined

# %%
#This block was to double check that the byte string and the test string are the same thing

#test_cards = "Posts frequently on social media" 
#if (test_cards==final_card):
#    print ("Decoding successful")
#else : print ("Decoding Unsuccessful")

#print(repr(final_card))
#print(repr(test_cards))

# %%
import random
model_list = ["Risk Model", "Unpredictability Model", "Concealment Model", "Obsession Model"]
picked = random.randrange(0, 3)

model_picked = []
model_picked.append(model_list[picked])

# %%
import pandas
cards = pandas.read_csv("behavioural_surplus.csv")
cards[cards.columns] = cards[cards.columns] * 1.5

cards.to_csv("cards_15.csv", index=False)
cards
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas
#       2 cards = pandas.read_csv("behavioural_surplus.csv")
# ----> 3 cards[cards.columns] = cards[cards.columns] * 1.5
#       5 cards.to_csv("cards_15.csv", index=False)
#       6 cards
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\frame.py:7913, in DataFrame._arith_method(self, other, op)
#    7910 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7912 with np.errstate(all="ignore"):
# -> 7913     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7914 return self._construct_result(new_data)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\frame.py:7945, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7942 right = lib.item_from_zerodim(right)
#    7943 if not is_list_like(right):
#    7944     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7945     bm = self._mgr.apply(array_op, right=right)
#    7946     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7948 elif isinstance(right, DataFrame):
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File c:\Users\Elune\miniconda3\envs\big-data-venv\Lib\site-packages\pandas\core\ops\array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
collected_cards = [1, 3]
score_tally = []
for i in collected_cards:
    card_finder = cards.iloc[i]
    score = card_finder[model_picked].item()

    cards.loc[i, ' Player One'] += 1
    if cards.loc[i, ' Player One'] == 3:
        print("You can use", card_finder['Card'], "only once more")
    if cards.loc[i, ' Player One'] >= 4:
        print("You've used", card_finder['Card'], "too much")
        break
    else:
        score_tally.append(score)

cards
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 score_tally = []
#       3 for i in collected_cards:
# ----> 4     card_finder = cards.iloc[i]
#       5     score = card_finder[model_picked].item()
#       7     cards.loc[i, ' Player One'] += 1
#
# NameError: name 'cards' is not defined

# %%
turn_score = 0

for item in score_tally:
    turn_score += item

print(turn_score)
# Out:
# 2
