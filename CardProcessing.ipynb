# %% [markdown]
# <h1>Card Processing</h1>
# <p>This program reads the serial port from COM4 (Arduino Leonardo running the NFC-Input code) and saves the data a a string. The data exported from the ardunio are the behavioural surplus cards' NFC reader tags, written in the app "NFC Tools" for the IPhone.</p>

# %%
#pip install pyserial
print("This is here to show that the import is working")

# %%
#Importing a module for reading serial communications
import serial

#Connecting to COM4 where the Arduino's USB is connected at with a baud rate of 9600 (same as the "NFC-Input" program)
ser = serial.Serial('COM4', 9600, timeout=1)
print(f"Connected to {ser.name}")
# Out:
# Connected to COM4

# %%
#If there's bytes waiting at the input buffer, read them and save them to a card variable
if ser.in_waiting > 0:
    available = ser.read(ser.in_waiting)
    print(f"Available data: {available}")
    card = available
# Out:
# Available data: b'31\r\n\r\n\r\n\r\n'

# %%
#As the card variable is a byte, convert card to a string using utf-8 \r\n\r\n\r\n\r\n
#print(type(card))
decode_card = card.decode("UTF-8")
#clean_card = decode_card[5:]
#clean_card = final_card[:-4]
#final_card = clean_card.strip()
#clean_card = decode_card.strip()
clean_card = decode_card.split()
final_card = [int(i) for i in clean_card]
print(final_card)
# Out:
# [31]

# %%
#This block was to double check that the byte string and the test string are the same thing

#test_cards = "Posts frequently on social media" 
#if (test_cards==final_card):
#    print ("Decoding successful")
#else : print ("Decoding Unsuccessful")

#print(repr(final_card))
#print(repr(test_cards))

# %%
import random
model_list = ["Risk Model", "Unpredictability Model", "Concealment Model", "Obsession Model"]
picked = random.randrange(0, 3)

model_picked = []
model_picked.append(model_list[picked])
model_picked
# Out:
# ['Unpredictability Model']

# %%
import pandas

cards = pandas.read_csv("behavioural_surplus.csv")
cards[1:50]
# Out:
#            Room                                               Card  \
# 1         Study   "Tracks personal health metrics manually usin...
# 2         Study   "Uses private browsing mode regularly when br...
# 3         Study   "Clears browser history often after internet ...
# 4         Study                "Maintains minimal online presence"
# 5         Study   "Tracks time spent on tasks using productivit...
# 6         Study      "Watches Climate Change documentaries at 3am"
# 7         Study   "Uses productivity apps daily to organise dig...
# 8       Bedroom   "Visits NHS or medical websites frequently vi...
# 9       Bedroom   "Searches symptoms late at night on social pl...
# 10      Bedroom   "Wakes up at the same time every day and chec...
# 11      Bedroom                 "Posts frequently on social media"
# 12      Bedroom   "Oversleeps on work days after late-night dev...
# 13      Bedroom               "Often active online after midnight"
# 14      Bedroom                "Deletes posts with low engagement"
# 15      Bedroom   "Social media post suggests they rarely spend...
# 16  Living room       "Cancels plans on short notice with friends"
# 17  Living room              "Has no active social media accounts"
# 18  Living room   "Rarely initiates conversations in social set...
# 19  Living room                "Leaves home at inconsistent times"
# 20  Living room     "Checks online maps often in their local area"
# 21  Living room            "Travel patterns do not follow routine"
# 22  Living room          "Frequently changes location on weekends"
# 23  Living room      "Goes to the local pub multiple times a week"
# 24      Kitchen         "Buys vitamins and supplements frequently"
# 25      Kitchen   "Rarely uses loyalty cards or subscriptions w...
# 26      Kitchen                   "Few recorded purchasing habits"
# 27      Kitchen     "Rarely makes impulse purchases when shopping"
# 28      Kitchen               "Eats takeaway at a consistant time"
# 29      Kitchen    "Checks bank balance daily to monitor finances"
# 30      Kitchen           "Exercises at scheduled times each week"
# 31      Kitchen   "Spends more money when socialising on food a...
#
#     Risk Model  Unpredictability Model  Concealment Model  Obsession Model
# 1            9                      -9                -10               12
# 2            8                      -7                 14               -6
# 3           10                       4                 15               -5
# 4          -10                       6                 13               -8
# 5            7                     -11                 -8               10
# 6           11                       9                 -2                6
# 7            6                      -8                 -6               13
# 8            9                       4                  3               12
# 9           13                       6                 -5               10
# 10           5                     -14                 -4               14
# 11          -9                      -6                -12               11
# 12          -7                      10                  2               -8
# 13           4                       8                  9               -6
# 14          11                       7                 10               14
# 15           4                      13                  3               -7
# 16          -6                      14                  6               -5
# 17         -12                       5                 13               -6
# 18           8                       5                  8               -9
# 19          -5                      15                  9              -10
# 20           7                       4                 -4                5
# 21           5                      14                  4               -5
# 22          -8                      15                  5               -4
# 23          -8                       6                 -6               -7
# 24           5                       3                  4               12
# 25          -6                     -11                 10               -5
# 26          -5                      -8                 12               -6
# 27           6                     -12                -10               -4
# 28           4                     -10                 -4                6
# 29          11                       9                 -3                7
# 30          -5                     -11                 -5               12
# 31           8                       6                 -4               -3

# %%
score_tally = []
for i in final_card:
    card_finder = cards.iloc[i]
    #print(card_finder)
    score = card_finder[model_picked].item()
    score_tally.append(score)
print(score_tally)
# Out:
# [5]

# %%
turn_score = 0

for item in score_tally:
    turn_score += item

print(turn_score)
# Out:
# 5
